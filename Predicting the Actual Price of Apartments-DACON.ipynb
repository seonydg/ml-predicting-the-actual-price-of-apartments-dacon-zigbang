# %% [markdown]
# # 데이터 확인

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'../data/ml-predicting-the-actual-price-of-apartments-dacon-zigbang/sampled_train.csv')

df
# Out:
#        transaction_id  apartment_id   city     dong jibun         apt  \
# 0               10923          1878  서울특별시      신당동   844        남산타운
# 1               10924          1878  서울특별시      신당동   844        남산타운
# 2               10927          1878  서울특별시      신당동   844        남산타운
# 3               10928          1878  서울특별시      신당동   844        남산타운
# 4               10930          1878  서울특별시      신당동   844        남산타운
# ...               ...           ...    ...      ...   ...         ...
# 36011         1234627          9587  부산광역시  정관읍 용수리  1403  정관신도시한진해모로
# 36012         1234712          9587  부산광역시  정관읍 용수리  1403  정관신도시한진해모로
# 36013         1234715          9587  부산광역시  정관읍 용수리  1403  정관신도시한진해모로
# 36014         1234717          9587  부산광역시  정관읍 용수리  1403  정관신도시한진해모로
# 36015         1234822          9587  부산광역시  정관읍 용수리  1403  정관신도시한진해모로
#
#                        addr_kr  exclusive_use_area  year_of_completion  \
# 0                 신당동 844 남산타운             84.8800                2002
# 1                 신당동 844 남산타운             84.8800                2002
# 2                 신당동 844 남산타운            114.8800                2002
# 3                 신당동 844 남산타운            114.8800                2002
# 4                 신당동 844 남산타운             84.8800                2002
# ...                        ...                 ...                 ...
# 36011  정관읍 용수리 1403 정관신도시한진해모로            109.3076                2008
# 36012  정관읍 용수리 1403 정관신도시한진해모로            135.6199                2008
# 36013  정관읍 용수리 1403 정관신도시한진해모로            109.3076                2008
# 36014  정관읍 용수리 1403 정관신도시한진해모로            135.6199                2008
# 36015  정관읍 용수리 1403 정관신도시한진해모로            109.3076                2008
#
#        transaction_year_month transaction_date  floor  transaction_real_price
# 0                      201601             1~10      3                   52000
# 1                      201601             1~10     10                   58000
# 2                      201601             1~10     11                   91500
# 3                      201601            11~20     13                   72000
# 4                      201601            11~20      6                   68300
# ...                       ...              ...    ...                     ...
# 36011                  201709            21~30      2                   33900
# 36012                  201710            11~20     10                   40000
# 36013                  201710            11~20     12                   36500
# 36014                  201710            11~20     13                   41500
# 36015                  201711            11~20      5                   36000
#
# [36016 rows x 13 columns]

# %%
test_df = pd.read_csv(r'../data/ml-predicting-the-actual-price-of-apartments-dacon-zigbang/sampled_test.csv')

test_df
# Out:
#      transaction_id  apartment_id   city  dong  jibun          apt  \
# 0           1197195          4018  서울특별시   암사동  414-2      롯데캐슬퍼스트
# 1           1190777           520  서울특별시   가락동    140  가락(1차)쌍용아파트
# 2           1197165          6467  서울특별시   암사동    509      선사현대아파트
# 3           1179572           731  서울특별시   개포동    189     개포주공 4단지
# 4           1131476          5950  서울특별시   상계동    626   상계주공14(고층)
# ..              ...           ...    ...   ...    ...          ...
# 384         1162728          8272  서울특별시  영등포동    647      영등포푸르지오
# 385         1214400         12432  부산광역시   화명동   2324    화명롯데캐슬카이저
# 386         1210776          8415  부산광역시   용호동    944     오륙도에스케이뷰
# 387         1190462         10909  서울특별시   잠실동     35         트리지움
# 388         1190418          9436  서울특별시   잠실동     19         잠실엘스
#
#                  addr_kr  exclusive_use_area  year_of_completion  \
# 0      암사동 414-2 롯데캐슬퍼스트             102.340                2008
# 1    가락동 140 가락(1차)쌍용아파트              59.920                1997
# 2        암사동 509 선사현대아파트              59.640                2000
# 3       개포동 189 개포주공 4단지              50.670                1982
# 4     상계동 626 상계주공14(고층)              90.940                1989
# ..                   ...                 ...                 ...
# 384     영등포동 647 영등포푸르지오              79.777                2002
# 385   화명동 2324 화명롯데캐슬카이저             115.030                2012
# 386     용호동 944 오륙도에스케이뷰             123.307                2008
# 387          잠실동 35 트리지움             114.700                2007
# 388          잠실동 19 잠실엘스              59.960                2008
#
#      transaction_year_month transaction_date  floor
# 0                    201712            21~31      9
# 1                    201712            21~31     15
# 2                    201712            21~31      6
# 3                    201707             1~10      3
# 4                    201712            11~20      6
# ..                      ...              ...    ...
# 384                  201712            11~20     13
# 385                  201712            11~20     30
# 386                  201712            11~20     33
# 387                  201712            21~31     18
# 388                  201712            11~20      8
#
# [389 rows x 12 columns]

# %%
park_df = pd.read_csv(r'../data/ml-predicting-the-actual-price-of-apartments-dacon-zigbang/park.csv')

park_df
# Out:
#        city   gu dong  park_name park_type  park_area park_exercise_facility  \
# 0     부산광역시   남구  대연동       대연공원      근린공원    55227.0                    NaN
# 1     부산광역시   남구  대연동       당곡공원      역사공원    75465.0                    NaN
# 2     부산광역시   남구  대연동    대일어린이공원     어린이공원      422.1                    NaN
# 3     부산광역시   남구  대연동    못골어린이공원     어린이공원      499.8                    NaN
# 4     부산광역시   남구  용호동    솔밭어린이공원     어린이공원     1500.2                    NaN
# ...     ...  ...  ...        ...       ...        ...                    ...
# 1354  서울특별시  구로구  천왕동  이펜시아어린이공원     어린이공원     1500.0                    NaN
# 1355  서울특별시  구로구  천왕동      개명소공원       소공원     5415.0                    NaN
# 1356  서울특별시  구로구  천왕동    봉화대근린공원      근린공원    60975.0                    NaN
# 1357  서울특별시  구로구   항동      푸른수목원      근린공원   100809.0                    NaN
# 1358  서울특별시  구로구  오류동   오류동역문화공원      문화공원     7510.0                    NaN
#
#      park_entertainment_facility park_benefit_facility park_cultural_facitiy  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                   NaN                   NaN
# 2                            NaN                   NaN                   NaN
# 3                            NaN                   NaN                   NaN
# 4                            NaN                   NaN                   NaN
# ...                          ...                   ...                   ...
# 1354                     조합놀이 1기                   NaN                   NaN
# 1355                         NaN                   NaN                   NaN
# 1356                         NaN                   NaN                   NaN
# 1357                         NaN                   NaN                   NaN
# 1358                         NaN                   NaN                   NaN
#
#      park_facility_other  park_open_year reference_date
# 0                    NaN          1944.0     2018-08-14
# 1                    NaN          1944.0     2018-08-14
# 2                    NaN          1965.0     2018-08-14
# 3                    NaN          1968.0     2018-08-14
# 4                    NaN          1970.0     2018-08-14
# ...                  ...             ...            ...
# 1354                 NaN          2006.0     2019-02-25
# 1355                 NaN          2006.0     2019-02-25
# 1356                 NaN          2006.0     2019-02-25
# 1357                 NaN          2005.0     2019-02-25
# 1358                 NaN          2013.0     2019-02-25
#
# [1359 rows x 13 columns]

# %%
day_care_center_df = pd.read_csv(r'../data/ml-predicting-the-actual-price-of-apartments-dacon-zigbang/day_care_center.csv')

day_care_center_df
# Out:
#        city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 0     서울특별시  서대문구        가람어린이집           국공립                 70         11.0
# 1     서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 2     서울특별시  서대문구       경찰청어린이집            직장                 90         23.0
# 3     서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 4     서울특별시  서대문구        고은어린이집           국공립                 93         20.0
# ...     ...   ...           ...           ...                ...          ...
# 7546  부산광역시   금정구      해바라기어린이집            민간                 46         13.0
# 7547  부산광역시   금정구        해수어린이집            가정                 19          6.0
# 7548  부산광역시   금정구   행복한그림동산어린이집            민간                 92         16.0
# 7549  부산광역시   금정구       행복한어린이집            민간                 43         12.0
# 7550  부산광역시   금정구        혜인어린이집            민간                 32          7.0
#
#       nursing_room_num  playground_num  CCTV_num is_commuting_vehicle  \
# 0                  5.0             1.0       7.0                    N
# 1                  5.0             2.0      10.0                    N
# 2                  6.0             1.0      32.0                    N
# 3                  3.0             0.0       4.0                    N
# 4                  7.0             2.0      10.0                    N
# ...                ...             ...       ...                  ...
# 7546               NaN             NaN       NaN                    y
# 7547               NaN             NaN       NaN                    y
# 7548               NaN             NaN       NaN                    y
# 7549               NaN             NaN       NaN                    y
# 7550               NaN             NaN       NaN                    y
#
#      reference_date
# 0        2018-07-31
# 1        2018-07-31
# 2        2018-07-31
# 3        2018-07-31
# 4        2018-07-31
# ...             ...
# 7546     2019-01-21
# 7547     2019-01-21
# 7548     2019-01-21
# 7549     2019-01-21
# 7550     2019-01-21
#
# [7551 rows x 11 columns]

# %%
ref_df = pd.read_excel(r'../data/ml-predicting-the-actual-price-of-apartments-dacon-zigbang/한국행정구역분류.xlsx', sheet_name = "법정동코드 연계 자료분석용", header = 1)

ref_df
# Out:
# c:\Users\baebi\miniconda3\envs\ds_study\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#             시도    시군구  행정구역명 행정동(행정기관명)    법정동     행정구역코드      행정기관코드  \
# 0        서울특별시  서울특별시  서울특별시      서울특별시  서울특별시       11.0  1100000000
# 1        서울특별시    종로구    종로구        종로구    종로구    11010.0  1111000000
# 2        서울특별시    종로구  청운효자동      청운효자동    청운동  1101072.0  1111051500
# 3        서울특별시    종로구  청운효자동      청운효자동    신교동  1101072.0  1111051500
# 4        서울특별시    종로구  청운효자동      청운효자동    궁정동  1101072.0  1111051500
# ...        ...    ...    ...        ...    ...        ...         ...
# 21662  제주특별자치도   서귀포시    중문동        중문동    대포동  3902061.0  5013061000
# 21663  제주특별자치도   서귀포시    중문동        중문동    하원동  3902061.0  5013061000
# 21664  제주특별자치도   서귀포시    예래동        예래동    색달동  3902062.0  5013062000
# 21665  제주특별자치도   서귀포시    예래동        예래동    상예동  3902062.0  5013062000
# 21666  제주특별자치도   서귀포시    예래동        예래동    하예동  3902062.0  5013062000
#
#        행정기관 생성일       법정동코드 관할지역            행정동 영문명칭   비고
# 0      19880423  1100000000  NaN               Seoul  NaN
# 1      19880423  1111000000  NaN           Jongno-gu  NaN
# 2      20081101  1111010100  NaN  Cheongunhyoja-dong  NaN
# 3      20081101  1111010200  NaN  Cheongunhyoja-dong  NaN
# 4      20081101  1111010300  NaN  Cheongunhyoja-dong  NaN
# ...         ...         ...  ...                 ...  ...
# 21662  20060701  5013011400  NaN        Jungmun-dong  NaN
# 21663  20060701  5013011800  NaN        Jungmun-dong  NaN
# 21664  20060701  5013011900  NaN          Yerae-dong  NaN
# 21665  20060701  5013012000  NaN          Yerae-dong  NaN
# 21666  20060701  5013012100  NaN          Yerae-dong  NaN
#
# [21667 rows x 12 columns]

# %% [markdown]
# # 탐색 및 전처리

# %% [markdown]
# # 데이터 병합

# %% [markdown]
# # 모델링
